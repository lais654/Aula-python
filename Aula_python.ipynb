# %% [markdown]
# <a href="https://colab.research.google.com/github/lais654/Aula-python/blob/main/Aula_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Atividade 1

# %%
nome = "joao Silva"
idade = 25
profissao = "desenvolvedor"

print ("nome:", nome)
print ("idade:", idade)
print ("profissao:", profissao)
# Out:
# nome: joao Silva
# idade: 25
# profissao: desenvolvedor

# %% [markdown]
# Atividade 2

# %%
produto = "notebook"
marca = "Dell"
preco = 4500

print ("produto:", produto)
print ("marca:", marca)
print (f"preco R${preco:.2f}")
# Out:
# produto: notebook
# marca: Dell
# preco R$4500.00

# %% [markdown]
# Atividade 3

# %%
num1 = 12
num2 = 6
soma = (num1 + num2)
subtracao = (num1 - num2)
mult = (num1 * num2)
divisao = (num1 / num2)

print ("numero 1:", num1)
print ("numero 2:", num2)

print ("soma:", soma)
print ("subtração:", subtracao)
print ("multiplicação:", mult)
print ("divisão:", divisao)
# Out:
# numero 1: 12
# numero 2: 6
# soma: 18
# subtração: 6
# multiplicação: 72
# divisão: 2.0

# %% [markdown]
# Atividade 4

# %%
num1 = 7
num2 = 2
soma = num1 + num2
subtracao = num1 - num2
mult = num1 * num2
divisao = num1 / num2
pot = num1 ** num2

print ("soma:", soma)
print ("subtração:", subtracao)
print ("multiplicação:", mult)
print ("divisão:", divisao)
print ("potenciação:", pot)
# Out:
# soma: 9
# subtração: 5
# multiplicação: 14
# divisão: 3.5
# potenciação: 49
